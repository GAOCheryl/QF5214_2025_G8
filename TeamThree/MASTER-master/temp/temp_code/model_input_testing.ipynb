# %%
#from master import MASTERModel
import pickle
import numpy as np
import time
import pandas as pd
import sys, os
import qlib
from qlib.data.dataset import TSDataSampler

# Move up one directory from MASTER-master
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)


from alpha_101.alpha_generator import get_alpha101_table_from_db
from alpha_101.alpha_generator import generate_alphas

# %%
# Call generate_alphas() which returns (df, final_df)
df, final_df = generate_alphas(input_schema = 'datacollection',
                    input_table_name = 'stock_data',
                    save = True, 
                    output_schema = 'datacollection',
                    output_table_name = 'alpha101',
                    if_return = True)
# Out:
# Running function alpha001 for ADBE...
# Running function alpha002 for ADBE...
# Running function alpha003 for ADBE...
# Running function alpha004 for ADBE...
# Running function alpha006 for ADBE...
# Running function alpha007 for ADBE...
# Running function alpha008 for ADBE...
# Running function alpha009 for ADBE...
# Running function alpha010 for ADBE...
# Running function alpha011 for ADBE...
# Running function alpha012 for ADBE...
# Running function alpha013 for ADBE...
# Running function alpha014 for ADBE...
# Running function alpha015 for ADBE...
# Running function alpha016 for ADBE...
# Running function alpha017 for ADBE...
# Running function alpha018 for ADBE...
# Running function alpha019 for ADBE...
# Running function alpha020 for ADBE...
# Running function alpha021 for ADBE...
# Running function alpha022 for ADBE...
# Running function alpha023 for ADBE...
# Running function alpha024 for ADBE...
# Running function alpha025 for ADBE...
# Running function alpha026 for ADBE...
# Running function alpha028 for ADBE...
# Running function alpha029 for ADBE...
# Running function alpha030 for ADBE...
# Running function alpha031 for ADBE...
# Running function alpha032 for ADBE...
# Running function alpha033 for ADBE...
# Running function alpha034 for ADBE...
# Running function alpha035 for ADBE...
# Running function alpha036 for ADBE...
# Running function alpha037 for ADBE...
# Running function alpha038 for ADBE...
# Running function alpha039 for ADBE...
# Running function alpha040 for ADBE...
# Running function alpha041 for ADBE...
# Running function alpha042 for ADBE...
# Running function alpha043 for ADBE...
# Running function alpha044 for ADBE...
# Running function alpha045 for ADBE...
# Running function alpha046 for ADBE...
# Running function alpha047 for ADBE...
# Running function alpha048 for ADBE...
# Running function alpha049 for ADBE...
# Running function alpha050 for ADBE...
# Running function alpha051 for ADBE...
# Running function alpha052 for ADBE...
# Running function alpha053 for ADBE...
# Running function alpha054 for ADBE...
# Running function alpha055 for ADBE...
# Running function alpha056 for ADBE...
# Running function alpha057 for ADBE...
# Running function alpha058 for ADBE...
# Running function alpha060 for ADBE...
# Running function alpha061 for ADBE...
# Running function alpha062 for ADBE...
# Running function alpha063 for ADBE...
# Running function alpha064 for ADBE...
# Running function alpha065 for ADBE...
# Running function alpha066 for ADBE...
# Running function alpha071 for ADBE...
# Running function alpha072 for ADBE...
# Running function alpha073 for ADBE...
# Running function alpha074 for ADBE...
# Running function alpha075 for ADBE...
# Running function alpha076 for ADBE...
# Running function alpha077 for ADBE...
# Running function alpha078 for ADBE...
# Running function alpha079 for ADBE...
# Running function alpha081 for ADBE...
# Running function alpha082 for ADBE...
# Running function alpha083 for ADBE...
# Running function alpha084 for ADBE...
# Running function alpha085 for ADBE...
# Running function alpha087 for ADBE...
# Running function alpha088 for ADBE...
# Running function alpha089 for ADBE...
# Running function alpha092 for ADBE...
# Running function alpha093 for ADBE...
# Running function alpha094 for ADBE...
# Running function alpha096 for ADBE...
# Running function alpha097 for ADBE...
# Running function alpha098 for ADBE...
# Running function alpha099 for ADBE...
# Running function alpha101 for ADBE...
# Running function alpha001 for AMD...
# Running function alpha002 for AMD...
# Running function alpha003 for AMD...
# Running function alpha004 for AMD...
# Running function alpha006 for AMD...
# Running function alpha007 for AMD...
# Running function alpha008 for AMD...
# Running function alpha009 for AMD...
# Running function alpha010 for AMD...
# Running function alpha011 for AMD...
# Running function alpha012 for AMD...
# Running function alpha013 for AMD...
# Running function alpha014 for AMD...
# Running function alpha015 for AMD...
# Running function alpha016 for AMD...
# Running function alpha017 for AMD...
# Running function alpha018 for AMD...
# Running function alpha019 for AMD...
# Running function alpha020 for AMD...
# Running function alpha021 for AMD...
# Running function alpha022 for AMD...
# Running function alpha023 for AMD...
# Running function alpha024 for AMD...
# Running function alpha025 for AMD...
# Running function alpha026 for AMD...
# Running function alpha028 for AMD...
# Running function alpha029 for AMD...
# Running function alpha030 for AMD...
# Running function alpha031 for AMD...
# Running function alpha032 for AMD...
# Running function alpha033 for AMD...
# Running function alpha034 for AMD...
# Running function alpha035 for AMD...
# Running function alpha036 for AMD...
# Running function alpha037 for AMD...
# Running function alpha038 for AMD...
# Running function alpha039 for AMD...
# Running function alpha040 for AMD...
# Running function alpha041 for AMD...
# Running function alpha042 for AMD...
# Running function alpha043 for AMD...
# Running function alpha044 for AMD...
# Running function alpha045 for AMD...
# Running function alpha046 for AMD...
# Running function alpha047 for AMD...
# Running function alpha048 for AMD...
# Running function alpha049 for AMD...
# Running function alpha050 for AMD...
# Running function alpha051 for AMD...
# Running function alpha052 for AMD...
# Running function alpha053 for AMD...
# Running function alpha054 for AMD...
# Running function alpha055 for AMD...
# Running function alpha056 for AMD...
# Running function alpha057 for AMD...
# Running function alpha058 for AMD...
# Running function alpha060 for AMD...
# Running function alpha061 for AMD...
# Running function alpha062 for AMD...
# Running function alpha063 for AMD...
# Running function alpha064 for AMD...
# Running function alpha065 for AMD...
# Running function alpha066 for AMD...
# Running function alpha071 for AMD...
# Running function alpha072 for AMD...
# Running function alpha073 for AMD...
# Running function alpha074 for AMD...
# Running function alpha075 for AMD...
# Running function alpha076 for AMD...
# Running function alpha077 for AMD...
# Running function alpha078 for AMD...
# Running function alpha079 for AMD...
# Running function alpha081 for AMD...
# Running function alpha082 for AMD...
# Running function alpha083 for AMD...
# Running function alpha084 for AMD...
# Running function alpha085 for AMD...
# Running function alpha087 for AMD...
# Running function alpha088 for AMD...
# Running function alpha089 for AMD...
# Running function alpha092 for AMD...
# Running function alpha093 for AMD...
# Running function alpha094 for AMD...
# Running function alpha096 for AMD...
# Running function alpha097 for AMD...
# Running function alpha098 for AMD...
# Running function alpha099 for AMD...
# Running function alpha101 for AMD...
# Running function alpha001 for ABNB...
# Running function alpha002 for ABNB...
# Running function alpha003 for ABNB...
# Running function alpha004 for ABNB...
# Running function alpha006 for ABNB...
# Running function alpha007 for ABNB...
# Running function alpha008 for ABNB...
# Running function alpha009 for ABNB...
# Running function alpha010 for ABNB...
# Running function alpha011 for ABNB...
# Running function alpha012 for ABNB...
# Running function alpha013 for ABNB...
# Running function alpha014 for ABNB...
# Running function alpha015 for ABNB...
# Running function alpha016 for ABNB...
# Running function alpha017 for ABNB...
# Running function alpha018 for ABNB...
# Running function alpha019 for ABNB...
# Running function alpha020 for ABNB...
# Running function alpha021 for ABNB...
# Running function alpha022 for ABNB...
# Running function alpha023 for ABNB...
# Running function alpha024 for ABNB...
# Running function alpha025 for ABNB...
# Running function alpha026 for ABNB...
# Running function alpha028 for ABNB...
# Running function alpha029 for ABNB...
# Running function alpha030 for ABNB...
# Running function alpha031 for ABNB...
# Running function alpha032 for ABNB...
# Running function alpha033 for ABNB...
# Running function alpha034 for ABNB...
# Running function alpha035 for ABNB...
# Running function alpha036 for ABNB...
# Running function alpha037 for ABNB...
# Running function alpha038 for ABNB...
# Running function alpha039 for ABNB...
# Running function alpha040 for ABNB...
# Running function alpha041 for ABNB...
# Running function alpha042 for ABNB...
# Running function alpha043 for ABNB...
# Running function alpha044 for ABNB...
# Running function alpha045 for ABNB...
# Running function alpha046 for ABNB...
# Running function alpha047 for ABNB...
# Running function alpha048 for ABNB...
# Running function alpha049 for ABNB...
# Running function alpha050 for ABNB...
# Running function alpha051 for ABNB...
# Running function alpha052 for ABNB...
# Running function alpha053 for ABNB...
# Running function alpha054 for ABNB...
# Running function alpha055 for ABNB...
# Running function alpha056 for ABNB...
# Running function alpha057 for ABNB...
# Running function alpha058 for ABNB...
# Running function alpha060 for ABNB...
# Running function alpha061 for ABNB...
# Running function alpha062 for ABNB...
# Running function alpha063 for ABNB...
# Running function alpha064 for ABNB...
# Running function alpha065 for ABNB...
# Running function alpha066 for ABNB...
# Running function alpha071 for ABNB...
# Running function alpha072 for ABNB...
# Running function alpha073 for ABNB...
# Running function alpha074 for ABNB...
# Running function alpha075 for ABNB...
# Running function alpha076 for ABNB...
# Running function alpha077 for ABNB...
# Running function alpha078 for ABNB...
# Running function alpha079 for ABNB...
# Running function alpha081 for ABNB...
# Running function alpha082 for ABNB...
# Running function alpha083 for ABNB...
# Running function alpha084 for ABNB...
# Running function alpha085 for ABNB...
# Running function alpha087 for ABNB...
# Running function alpha088 for ABNB...
# Running function alpha089 for ABNB...
# Running function alpha092 for ABNB...
# Running function alpha093 for ABNB...
# Running function alpha094 for ABNB...
# Running function alpha096 for ABNB...
# Running function alpha097 for ABNB...
# Running function alpha098 for ABNB...
# Running function alpha099 for ABNB...
# Running function alpha101 for ABNB...
# Running function alpha001 for GOOGL...
# Running function alpha002 for GOOGL...
# Running function alpha003 for GOOGL...
# Running function alpha004 for GOOGL...
# Running function alpha006 for GOOGL...
# Running function alpha007 for GOOGL...
# Running function alpha008 for GOOGL...
# Running function alpha009 for GOOGL...
# Running function alpha010 for GOOGL...
# Running function alpha011 for GOOGL...
# Running function alpha014 for GOOG...
# Running function alpha015 for GOOG...
# Running function alpha016 for GOOG...
# Running function alpha017 for GOOG...
# Running function alpha018 for GOOG...
# Running function alpha019 for GOOG...
# Running function alpha020 for GOOG...
# Running function alpha021 for GOOG...
# Running function alpha022 for GOOG...
# Running function alpha023 for GOOG...
# Running function alpha024 for GOOG...
# Running function alpha025 for GOOG...
# Running function alpha026 for GOOG...
# Running function alpha028 for GOOG...
# Running function alpha029 for GOOG...
# Running function alpha030 for GOOG...
# Running function alpha031 for GOOG...
# Running function alpha032 for GOOG...
# Running function alpha033 for GOOG...
# Running function alpha034 for GOOG...
# Running function alpha035 for GOOG...
# Running function alpha036 for GOOG...
# Running function alpha037 for GOOG...
# Running function alpha038 for GOOG...
# Running function alpha039 for GOOG...
# Running function alpha040 for GOOG...
# Running function alpha041 for GOOG...
# Running function alpha042 for GOOG...
# Running function alpha043 for GOOG...
# Running function alpha044 for GOOG...
# Running function alpha045 for GOOG...
# Running function alpha046 for GOOG...
# Running function alpha047 for GOOG...
# Running function alpha048 for GOOG...
# Running function alpha049 for GOOG...
# Running function alpha050 for GOOG...
# Running function alpha051 for GOOG...
# Running function alpha052 for GOOG...
# Running function alpha053 for GOOG...
# Running function alpha054 for GOOG...
# Running function alpha055 for GOOG...
# Running function alpha056 for GOOG...
# Running function alpha057 for GOOG...
# Running function alpha058 for GOOG...
# Running function alpha060 for GOOG...
# Running function alpha061 for GOOG...
# Running function alpha062 for GOOG...
# Running function alpha063 for GOOG...
# Running function alpha064 for GOOG...
# Running function alpha065 for GOOG...
# Running function alpha066 for GOOG...
# Running function alpha071 for GOOG...
# Running function alpha072 for GOOG...
# Running function alpha073 for GOOG...
# Running function alpha074 for GOOG...
# Running function alpha075 for GOOG...
# Running function alpha076 for GOOG...
# Running function alpha077 for GOOG...
# Running function alpha078 for GOOG...
# Running function alpha079 for GOOG...
# Running function alpha081 for GOOG...
# Running function alpha082 for GOOG...
# Running function alpha083 for GOOG...
# Running function alpha084 for GOOG...
# Running function alpha085 for GOOG...
# Running function alpha087 for GOOG...
# Running function alpha088 for GOOG...
# Running function alpha089 for GOOG...
# Running function alpha092 for GOOG...
# Running function alpha093 for GOOG...
# Running function alpha094 for GOOG...
# Running function alpha096 for GOOG...
# Running function alpha097 for GOOG...
# Running function alpha098 for GOOG...
# Running function alpha099 for GOOG...
# Running function alpha101 for GOOG...
# Running function alpha001 for AMZN...
# Running function alpha002 for AMZN...
# Running function alpha003 for AMZN...
# Running function alpha004 for AMZN...
# Running function alpha006 for AMZN...
# Running function alpha007 for AMZN...
# Running function alpha008 for AMZN...
# Running function alpha009 for AMZN...
# Running function alpha010 for AMZN...
# Running function alpha011 for AMZN...
# Running function alpha012 for AMZN...
# Running function alpha013 for AMZN...
# Running function alpha014 for AMZN...
# Running function alpha015 for AMZN...
# Running function alpha016 for AMZN...
# Running function alpha017 for AMZN...
# Running function alpha018 for AMZN...
# Running function alpha019 for AMZN...
# Running function alpha020 for AMZN...
# Running function alpha031 for AEP...
# Running function alpha032 for AEP...
# Running function alpha033 for AEP...
# Running function alpha034 for AEP...
# Running function alpha035 for AEP...
# Running function alpha036 for AEP...
# Running function alpha037 for AEP...
# Running function alpha038 for AEP...
# Running function alpha039 for AEP...
# Running function alpha040 for AEP...
# Running function alpha041 for AEP...
# Running function alpha042 for AEP...
# Running function alpha043 for AEP...
# Running function alpha044 for AEP...
# Running function alpha045 for AEP...
# Running function alpha046 for AEP...
# Running function alpha047 for AEP...
# Running function alpha048 for AEP...
# Running function alpha049 for AEP...
# Running function alpha050 for AEP...
# Running function alpha051 for AEP...
# Running function alpha052 for AEP...
# Running function alpha053 for AEP...
# Running function alpha054 for AEP...
# Running function alpha055 for AEP...
# Running function alpha056 for AEP...
# Running function alpha057 for AEP...
# Running function alpha058 for AEP...
# Running function alpha060 for AEP...
# Running function alpha061 for AEP...
# Running function alpha062 for AEP...
# Running function alpha063 for AEP...
# Running function alpha064 for AEP...
# Running function alpha065 for AEP...
# Running function alpha066 for AEP...
# Running function alpha071 for AEP...
# Running function alpha072 for AEP...
# Running function alpha073 for AEP...
# Running function alpha074 for AEP...
# Running function alpha075 for AEP...
# Running function alpha076 for AEP...
# Running function alpha077 for AEP...
# Running function alpha078 for AEP...
# Running function alpha079 for AEP...
# Running function alpha081 for AEP...
# Running function alpha082 for AEP...
# Running function alpha083 for AEP...
# Running function alpha084 for AEP...
# Running function alpha085 for AEP...
# Running function alpha087 for AEP...
# Running function alpha088 for AEP...
# Running function alpha089 for AEP...
# Running function alpha092 for AEP...
# Running function alpha093 for AEP...
# Running function alpha094 for AEP...
# Running function alpha096 for AEP...
# Running function alpha097 for AEP...
# Running function alpha098 for AEP...
# Running function alpha099 for AEP...
# Running function alpha101 for AEP...
# Running function alpha001 for AMGN...
# Running function alpha002 for AMGN...
# Running function alpha003 for AMGN...
# Running function alpha004 for AMGN...
# Running function alpha006 for AMGN...
# Running function alpha007 for AMGN...
# Running function alpha008 for AMGN...
# Running function alpha009 for AMGN...
# Running function alpha010 for AMGN...
# Running function alpha011 for AMGN...
# Running function alpha012 for AMGN...
# Running function alpha013 for AMGN...
# Running function alpha014 for AMGN...
# Running function alpha015 for AMGN...
# Running function alpha016 for AMGN...
# Running function alpha017 for AMGN...
# Running function alpha018 for AMGN...
# Running function alpha019 for AMGN...
# Running function alpha020 for AMGN...
# Running function alpha021 for AMGN...
# Running function alpha022 for AMGN...
# Running function alpha023 for AMGN...
# Running function alpha024 for AMGN...
# Running function alpha025 for AMGN...
# Running function alpha026 for AMGN...
# Running function alpha028 for AMGN...
# Running function alpha029 for AMGN...
# Running function alpha030 for AMGN...
# Running function alpha031 for AMGN...
# Running function alpha032 for AMGN...
# Running function alpha033 for AMGN...
# Running function alpha034 for AMGN...
# Running function alpha035 for AMGN...
# Running function alpha036 for AMGN...
# Running function alpha037 for AMGN...
# Running function alpha038 for AMGN...
# Running function alpha039 for AMGN...
# Running function alpha040 for AMGN...
# Running function alpha041 for AMGN...
# Running function alpha042 for AMGN...
# Running function alpha043 for AMGN...
# Running function alpha044 for AMGN...
# Running function alpha045 for AMGN...
# Running function alpha046 for AMGN...
# Running function alpha047 for AMGN...
# Running function alpha048 for AMGN...
# Running function alpha049 for AMGN...
# Running function alpha050 for AMGN...
# Running function alpha051 for AMGN...
# Running function alpha052 for AMGN...
# Running function alpha053 for AMGN...
# Running function alpha054 for AMGN...
# Running function alpha055 for AMGN...
# Running function alpha056 for AMGN...
# Running function alpha057 for AMGN...
# Running function alpha058 for AMGN...
# Running function alpha060 for AMGN...
# Running function alpha061 for AMGN...
# Running function alpha062 for AMGN...
# Running function alpha063 for AMGN...
# Running function alpha064 for AMGN...
# Running function alpha065 for AMGN...
# Running function alpha066 for AMGN...
# Running function alpha071 for AMGN...
# Running function alpha072 for AMGN...
# Running function alpha073 for AMGN...
# Running function alpha074 for AMGN...
# Running function alpha075 for AMGN...
# Running function alpha076 for AMGN...
# Running function alpha077 for AMGN...
# Running function alpha078 for AMGN...
# Running function alpha079 for AMGN...
# Running function alpha081 for AMGN...
# Running function alpha082 for AMGN...
# Running function alpha083 for AMGN...
# Running function alpha084 for AMGN...
# Running function alpha085 for AMGN...
# Running function alpha087 for AMGN...
# Running function alpha088 for AMGN...
# Running function alpha089 for AMGN...
# Running function alpha092 for AMGN...
# Running function alpha093 for AMGN...
# Running function alpha094 for AMGN...
# Running function alpha096 for AMGN...
# Running function alpha097 for AMGN...
# Running function alpha098 for AMGN...
# Running function alpha099 for AMGN...
# Running function alpha101 for AMGN...
# Running function alpha001 for ADI...
# Running function alpha002 for ADI...
# Running function alpha003 for ADI...
# Running function alpha004 for ADI...
# Running function alpha006 for ADI...
# Running function alpha007 for ADI...
# Running function alpha008 for ADI...
# Running function alpha009 for ADI...
# Running function alpha010 for ADI...
# Running function alpha011 for ADI...
# Running function alpha012 for ADI...
# Running function alpha013 for ADI...
# Running function alpha014 for ADI...
# Running function alpha015 for ADI...
# Running function alpha016 for ADI...
# Running function alpha017 for ADI...
# Running function alpha018 for ADI...
# Running function alpha019 for ADI...
# Running function alpha020 for ADI...
# Running function alpha021 for ADI...
# Running function alpha022 for ADI...
# Running function alpha023 for ADI...
# Running function alpha024 for ADI...
# Running function alpha025 for ADI...
# Running function alpha026 for ADI...
# Running function alpha028 for ADI...
# Running function alpha029 for ADI...
# Running function alpha030 for ADI...
# Running function alpha031 for ADI...
# Running function alpha032 for ADI...
# Running function alpha033 for ADI...
# Running function alpha034 for ADI...
# Running function alpha035 for ADI...
# Running function alpha036 for ADI...
# Running function alpha037 for ADI...
# Running function alpha038 for ADI...
# Running function alpha039 for ADI...
# Running function alpha040 for ADI...
# Running function alpha041 for ADI...
# Running function alpha042 for ADI...
# Running function alpha043 for ADI...
# Running function alpha044 for ADI...
# Running function alpha045 for ADI...
# Running function alpha046 for ADI...
# Running function alpha047 for ADI...
# Running function alpha048 for ADI...
# Running function alpha049 for ADI...
# Running function alpha050 for ADI...
# Running function alpha051 for ADI...
# Running function alpha052 for ADI...
# Running function alpha053 for ADI...
# Running function alpha054 for ADI...
# Running function alpha055 for ADI...
# Running function alpha056 for ADI...
# Running function alpha057 for ADI...
# Running function alpha058 for ADI...
# Running function alpha060 for ADI...
# Running function alpha061 for ADI...
# Running function alpha062 for ADI...
# Running function alpha063 for ADI...
# Running function alpha064 for ADI...
# Running function alpha065 for ADI...
# Running function alpha066 for ADI...
# Running function alpha071 for ADI...
# Running function alpha072 for ADI...
# Running function alpha073 for ADI...
# Running function alpha074 for ADI...
# Running function alpha075 for ADI...
# Running function alpha076 for ADI...
# Running function alpha077 for ADI...
# Running function alpha078 for ADI...
# Running function alpha079 for ADI...
# Running function alpha081 for ADI...
# Running function alpha082 for ADI...
# Running function alpha083 for ADI...
# Running function alpha084 for ADI...
# Running function alpha085 for ADI...
# Running function alpha087 for ADI...
# Running function alpha088 for ADI...
# Running function alpha089 for ADI...
# Running function alpha092 for ADI...
# Running function alpha093 for ADI...
# Running function alpha094 for ADI...
# Running function alpha096 for ADI...
# Running function alpha097 for ADI...
# Running function alpha098 for ADI...
# Running function alpha099 for ADI...
# Running function alpha101 for ADI...
# Running function alpha001 for ANSS...
# Running function alpha002 for ANSS...
# Running function alpha003 for ANSS...
# Running function alpha004 for ANSS...
# Running function alpha006 for ANSS...
# Running function alpha007 for ANSS...
# Running function alpha008 for ANSS...
# Running function alpha009 for ANSS...
# Running function alpha010 for ANSS...
# Running function alpha011 for ANSS...
# Running function alpha012 for ANSS...
# Running function alpha013 for ANSS...
# Running function alpha014 for ANSS...
# Running function alpha015 for ANSS...
# Running function alpha016 for ANSS...
# Running function alpha017 for ANSS...
# Running function alpha018 for ANSS...
# Running function alpha019 for ANSS...
# Running function alpha020 for ANSS...
# Running function alpha021 for ANSS...
# Running function alpha022 for ANSS...
# Running function alpha023 for ANSS...
# Running function alpha024 for ANSS...
# Running function alpha025 for ANSS...
# Running function alpha026 for ANSS...
# Running function alpha028 for ANSS...
# Running function alpha029 for ANSS...
# Running function alpha030 for ANSS...
# Running function alpha031 for ANSS...
# Running function alpha032 for ANSS...
# Running function alpha033 for ANSS...
# Running function alpha034 for ANSS...
# Running function alpha035 for ANSS...
# Running function alpha036 for ANSS...
# Running function alpha037 for ANSS...
# Running function alpha038 for ANSS...
# Running function alpha039 for ANSS...
# Running function alpha040 for ANSS...
# Running function alpha041 for ANSS...
# Running function alpha042 for ANSS...
# Running function alpha043 for ANSS...
# Running function alpha044 for ANSS...
# Running function alpha045 for ANSS...
# Running function alpha046 for ANSS...
# Running function alpha047 for ANSS...
# Running function alpha048 for ANSS...
# Running function alpha049 for ANSS...
# Running function alpha050 for ANSS...
# Running function alpha051 for ANSS...
# Running function alpha052 for ANSS...
# Running function alpha053 for ANSS...
# Running function alpha054 for ANSS...
# Running function alpha055 for ANSS...
# Running function alpha056 for ANSS...
# Running function alpha057 for ANSS...
# Running function alpha058 for ANSS...
# Running function alpha060 for ANSS...
# Running function alpha061 for ANSS...
# Running function alpha062 for ANSS...
# Running function alpha074 for AAPL...
# Running function alpha075 for AAPL...
# Running function alpha076 for AAPL...
# Running function alpha077 for AAPL...
# Running function alpha078 for AAPL...
# Running function alpha079 for AAPL...
# Running function alpha081 for AAPL...
# Running function alpha082 for AAPL...
# Running function alpha083 for AAPL...
# Running function alpha084 for AAPL...
# Running function alpha085 for AAPL...
# Running function alpha087 for AAPL...
# Running function alpha088 for AAPL...
# Running function alpha089 for AAPL...
# Running function alpha092 for AAPL...
# Running function alpha093 for AAPL...
# Running function alpha094 for AAPL...
# Running function alpha096 for AAPL...
# Running function alpha097 for AAPL...
# Running function alpha098 for AAPL...
# Running function alpha099 for AAPL...
# Running function alpha101 for AAPL...
# Running function alpha001 for AMAT...
# Running function alpha002 for AMAT...
# Running function alpha003 for AMAT...
# Running function alpha004 for AMAT...
# Running function alpha006 for AMAT...
# Running function alpha007 for AMAT...
# Running function alpha008 for AMAT...
# Running function alpha009 for AMAT...
# Running function alpha010 for AMAT...
# Running function alpha011 for AMAT...
# Running function alpha012 for AMAT...
# Running function alpha013 for AMAT...
# Running function alpha014 for AMAT...
# Running function alpha015 for AMAT...
# Running function alpha016 for AMAT...
# Running function alpha017 for AMAT...
# Running function alpha018 for AMAT...
# Running function alpha019 for AMAT...
# Running function alpha020 for AMAT...
# Running function alpha021 for AMAT...
# Running function alpha022 for AMAT...
# Running function alpha023 for AMAT...
# Running function alpha024 for AMAT...
# Running function alpha025 for AMAT...
# Running function alpha026 for AMAT...
# Running function alpha028 for AMAT...
# Running function alpha029 for AMAT...
# Running function alpha030 for AMAT...
# Running function alpha031 for AMAT...
# Running function alpha032 for AMAT...
# Running function alpha033 for AMAT...
# Running function alpha034 for AMAT...
# Running function alpha035 for AMAT...
# Running function alpha036 for AMAT...
# Running function alpha037 for AMAT...
# Running function alpha038 for AMAT...
# Running function alpha039 for AMAT...
# Running function alpha040 for AMAT...
# Running function alpha041 for AMAT...
# Running function alpha042 for AMAT...
# Running function alpha043 for AMAT...
# Running function alpha044 for AMAT...
# Running function alpha045 for AMAT...
# Running function alpha046 for AMAT...
# Running function alpha047 for AMAT...
# Running function alpha048 for AMAT...
# Running function alpha049 for AMAT...
# Running function alpha050 for AMAT...
# Running function alpha051 for AMAT...
# Running function alpha052 for AMAT...
# Running function alpha053 for AMAT...
# Running function alpha054 for AMAT...
# Running function alpha055 for AMAT...
# Running function alpha056 for AMAT...
# Running function alpha057 for AMAT...
# Running function alpha058 for AMAT...
# Running function alpha060 for AMAT...
# Running function alpha061 for AMAT...
# Running function alpha062 for AMAT...
# Running function alpha063 for AMAT...
# Running function alpha064 for AMAT...
# Running function alpha065 for AMAT...
# Running function alpha066 for AMAT...
# Running function alpha071 for AMAT...
# Running function alpha072 for AMAT...
# Running function alpha073 for AMAT...
# Running function alpha074 for AMAT...
# Running function alpha075 for AMAT...
# Running function alpha076 for AMAT...
# Running function alpha077 for AMAT...
# Running function alpha078 for AMAT...
# Running function alpha079 for AMAT...
# Running function alpha081 for AMAT...
# Running function alpha004 for ARM...
# Running function alpha006 for ARM...
# Running function alpha007 for ARM...
# Running function alpha008 for ARM...
# Running function alpha009 for ARM...
# Running function alpha010 for ARM...
# Running function alpha011 for ARM...
# Running function alpha012 for ARM...
# Running function alpha013 for ARM...
# Running function alpha014 for ARM...
# Running function alpha015 for ARM...
# Running function alpha016 for ARM...
# Running function alpha017 for ARM...
# Running function alpha018 for ARM...
# Running function alpha019 for ARM...
# Running function alpha020 for ARM...
# Running function alpha021 for ARM...
# Running function alpha022 for ARM...
# Running function alpha023 for ARM...
# Running function alpha024 for ARM...
# Running function alpha025 for ARM...
# Running function alpha026 for ARM...
# Running function alpha028 for ARM...
# Running function alpha029 for ARM...
# Running function alpha030 for ARM...
# Running function alpha031 for ARM...
# Running function alpha032 for ARM...
# Running function alpha033 for ARM...
# Running function alpha034 for ARM...
# Running function alpha035 for ARM...
# Running function alpha036 for ARM...
# Running function alpha037 for ARM...
# Running function alpha038 for ARM...
# Running function alpha039 for ARM...
# Running function alpha040 for ARM...
# Running function alpha041 for ARM...
# Running function alpha042 for ARM...
# Running function alpha043 for ARM...
# Running function alpha044 for ARM...
# Running function alpha045 for ARM...
# Running function alpha046 for ARM...
# Running function alpha047 for ARM...
# Running function alpha048 for ARM...
# Running function alpha049 for ARM...
# Running function alpha050 for ARM...
# Running function alpha051 for ARM...
# Running function alpha052 for ARM...
# Running function alpha053 for ARM...
# Running function alpha054 for ARM...
# Running function alpha055 for ARM...
# Running function alpha056 for ARM...
# Running function alpha057 for ARM...
# Running function alpha058 for ARM...
# Running function alpha060 for ARM...
# Running function alpha061 for ARM...
# Running function alpha062 for ARM...
# Running function alpha063 for ARM...
# Running function alpha064 for ARM...
# Running function alpha065 for ARM...
# Running function alpha066 for ARM...
# Running function alpha071 for ARM...
# Running function alpha072 for ARM...
# Running function alpha073 for ARM...
# Running function alpha074 for ARM...
# Running function alpha075 for ARM...
# Running function alpha076 for ARM...
# Running function alpha077 for ARM...
# Running function alpha078 for ARM...
# Running function alpha079 for ARM...
# Running function alpha081 for ARM...
# Running function alpha082 for ARM...
# Running function alpha083 for ARM...
# Running function alpha084 for ARM...
# Running function alpha085 for ARM...
# Running function alpha087 for ARM...
# Running function alpha088 for ARM...
# Running function alpha089 for ARM...
# Running function alpha092 for ARM...
# Running function alpha093 for ARM...
# Running function alpha094 for ARM...
# Running function alpha096 for ARM...
# Running function alpha097 for ARM...
# Running function alpha098 for ARM...
# Running function alpha099 for ARM...
# Running function alpha101 for ARM...
# Running function alpha001 for ASML...
# Running function alpha002 for ASML...
# Running function alpha003 for ASML...
# Running function alpha004 for ASML...
# Running function alpha006 for ASML...
# Running function alpha007 for ASML...
# Running function alpha008 for ASML...
# Running function alpha009 for ASML...
# Running function alpha010 for ASML...
# Running function alpha011 for ASML...
# Running function alpha012 for ASML...
# Running function alpha013 for ASML...
# Running function alpha014 for ASML...
# Running function alpha015 for ASML...
# Running function alpha016 for ASML...
# Running function alpha017 for ASML...
# Running function alpha018 for ASML...
# Running function alpha019 for ASML...
# Running function alpha020 for ASML...
# Running function alpha021 for ASML...
# Running function alpha022 for ASML...
# Running function alpha023 for ASML...
# Running function alpha024 for ASML...
# Running function alpha025 for ASML...
# Running function alpha026 for ASML...
# Running function alpha028 for ASML...
# Running function alpha029 for ASML...
# Running function alpha030 for ASML...
# Running function alpha031 for ASML...
# Running function alpha032 for ASML...
# Running function alpha033 for ASML...
# Running function alpha034 for ASML...
# Running function alpha035 for ASML...
# Running function alpha036 for ASML...
# Running function alpha037 for ASML...
# Running function alpha038 for ASML...
# Running function alpha039 for ASML...
# Running function alpha040 for ASML...
# Running function alpha041 for ASML...
# Running function alpha042 for ASML...
# ...
# Running function alpha012 for WBD...
# Running function alpha013 for WBD...
# Running function alpha014 for WBD...
# Running function alpha015 for WBD...
# Running function alpha016 for WBD...
# Running function alpha017 for WBD...
# Running function alpha018 for WBD...
# Running function alpha019 for WBD...
# Running function alpha020 for WBD...
# Running function alpha021 for WBD...
# Running function alpha022 for WBD...
# Running function alpha023 for WBD...
# Running function alpha024 for WBD...
# Running function alpha025 for WBD...
# Running function alpha026 for WBD...
# Running function alpha028 for WBD...
# Running function alpha029 for WBD...
# Running function alpha030 for WBD...
# Running function alpha031 for WBD...
# Running function alpha032 for WBD...
# Running function alpha033 for WBD...
# Running function alpha034 for WBD...
# Running function alpha035 for WBD...
# Running function alpha036 for WBD...
# Running function alpha037 for WBD...
# Running function alpha038 for WBD...
# Running function alpha039 for WBD...
# Running function alpha040 for WBD...
# Running function alpha041 for WBD...
# Running function alpha042 for WBD...
# Running function alpha043 for WBD...
# Running function alpha044 for WBD...
# Running function alpha045 for WBD...
# Running function alpha046 for WBD...
# Running function alpha047 for WBD...
# Running function alpha048 for WBD...
# Running function alpha049 for WBD...
# Running function alpha050 for WBD...
# Running function alpha051 for WBD...
# Running function alpha052 for WBD...
# Running function alpha053 for WBD...
# Running function alpha054 for WBD...
# Running function alpha055 for WBD...
# Running function alpha056 for WBD...
# Running function alpha057 for WBD...
# Running function alpha058 for WBD...
# Running function alpha060 for WBD...
# Running function alpha061 for WBD...
# Running function alpha062 for WBD...
# Running function alpha063 for WBD...
# Running function alpha064 for WBD...
# Running function alpha065 for WBD...
# Running function alpha066 for WBD...
# Running function alpha071 for WBD...
# Running function alpha072 for WBD...
# Running function alpha073 for WBD...
# Running function alpha074 for WBD...
# Running function alpha075 for WBD...
# Running function alpha076 for WBD...
# Running function alpha077 for WBD...
# Running function alpha078 for WBD...
# Running function alpha079 for WBD...
# Running function alpha081 for WBD...
# Running function alpha082 for WBD...
# Running function alpha083 for WBD...
# Running function alpha084 for WBD...
# Running function alpha085 for WBD...
# Running function alpha087 for WBD...
# Running function alpha088 for WBD...
# Running function alpha089 for WBD...
# Running function alpha092 for WBD...
# Running function alpha093 for WBD...
# Running function alpha094 for WBD...
# Running function alpha096 for WBD...
# Running function alpha097 for WBD...
# Running function alpha098 for WBD...
# Running function alpha099 for WBD...
# Running function alpha035 for CTAS...
# Running function alpha036 for CTAS...
# Running function alpha037 for CTAS...
# Running function alpha038 for CTAS...
# Running function alpha039 for CTAS...
# Running function alpha040 for CTAS...
# Running function alpha041 for CTAS...
# Running function alpha042 for CTAS...
# Running function alpha043 for CTAS...
# Running function alpha044 for CTAS...
# Running function alpha045 for CTAS...
# Running function alpha046 for CTAS...
# Running function alpha047 for CTAS...
# Running function alpha048 for CTAS...
# Running function alpha049 for CTAS...
# Running function alpha050 for CTAS...
# Running function alpha051 for CTAS...
# Running function alpha052 for CTAS...
# Running function alpha053 for CTAS...
# Running function alpha054 for CTAS...
# Running function alpha055 for CTAS...
# Running function alpha056 for CTAS...
# Running function alpha057 for CTAS...
# Running function alpha058 for CTAS...
# Running function alpha060 for CTAS...
# Running function alpha061 for CTAS...
# Running function alpha062 for CTAS...
# Running function alpha063 for CTAS...
# Running function alpha064 for CTAS...
# Running function alpha065 for CTAS...
# Running function alpha066 for CTAS...
# Running function alpha071 for CTAS...
# Running function alpha072 for CTAS...
# Running function alpha073 for CTAS...
# Running function alpha074 for CTAS...
# Running function alpha075 for CTAS...
# Running function alpha076 for CTAS...
# Running function alpha077 for CTAS...
# Running function alpha078 for CTAS...
# Running function alpha079 for CTAS...
# Running function alpha081 for CTAS...
# Running function alpha082 for CTAS...
# Running function alpha083 for CTAS...
# Running function alpha084 for CTAS...
# Running function alpha085 for CTAS...
# Running function alpha087 for CTAS...
# Running function alpha088 for CTAS...
# Running function alpha089 for CTAS...
# Running function alpha092 for CTAS...
# Running function alpha093 for CTAS...
# Running function alpha094 for CTAS...
# Running function alpha096 for CTAS...
# Running function alpha097 for CTAS...
# Running function alpha098 for CTAS...
# Running function alpha099 for CTAS...
# Running function alpha101 for CTAS...

# %%
df['Ticker'].unique()
# Out:
# <StringArray>
# [ 'ADBE',   'AMD',  'ABNB', 'GOOGL',  'GOOG',  'AMZN',   'AEP',  'AMGN',
#    'ADI',  'ANSS',
#  ...
#   'TSLA',   'TXN',   'TTD',  'VRSK',  'VRTX',   'WBD',  'WDAY',   'XEL',
#     'ZS',  'CTAS']
# Length: 101, dtype: string

# %%
company_list = ["ADBE", "AMD", "ABNB", "GOOGL", "GOOG", "AMZN", "AEP", "AMGN", 
"ADI", "ANSS", "AAPL", "AMAT", "APP", "ARM", "ASML", "AZN", 
"TEAM", "ADSK", "ADP", "AXON", "BKR", "BIIB", "BKNG", "AVGO", 
"CDNS", "CDW", "CHTR", "CTAS", "CSCO", "CCEP", "CTSH", "CMCSA", 
"CEG", "CPRT", "CSGP", "COST", "CRWD", "CSX", "DDOG", "DXCM","VRTX", "WBD", "WDAY", "XEL", "ZS","QCOM", "REGN", "ROP", "ROST" ]

# %%
df_all, final_df_all, df_index = get_alpha101_table_from_db()

# %%
# 1) Drop the "IndexTicker" column if it exists
df_index = df_index.drop(columns="IndexTicker", errors="ignore")

# 2) Pivot the DataFrame
df_index_pivot = df_index.pivot(
    index="Date",                # Each Date becomes a row
    columns="IndexName",         # Each unique IndexName becomes columns
    values=["Open", "High", "Low", "Close", "Adj_Close", "Volume"]
)

# 3) Flatten and rename columns to single-level format "<IndexName>_<Column>"
df_index_pivot.columns = [
    f"{col[1]}_{col[0]}"  # col is a tuple like ("Open", "S&P500")
    for col in df_index_pivot.columns
]

# %%
df_index_pivot = df_index_pivot.drop(columns=["Russell 1000_Volume", 
                                              "Russell 3000_Volume", 
                                              "Wilshire 5000_Volume"])


# 4) Move the 'Date' index back into a column
df_index_pivot.reset_index(inplace=True)

# Now df_index_pivot has columns like:
# ['Date', 'S&P500_Open', 'S&P500_High', 'S&P500_Low', 'S&P500_Close', 'S&P500_Adj_Close', 'S&P500_Volume', ...]

df_index_pivot
# Out:
#            Date  NASDAQ 100_Open  Russell 1000_Open  Russell 3000_Open  \
# 0    2022-01-03     16395.509766        2645.679932        2788.020020
# 1    2022-01-04     16513.869141        2660.989990        2788.020020
# 2    2022-01-05     16190.549805        2655.800049        2799.729980
# 3    2022-01-06     15675.219727        2600.379883        2739.229980
# 4    2022-01-07     15774.129883        2599.300049        2739.060059
# ..          ...              ...                ...                ...
# 802  2025-03-17     19670.689453        3079.219971        3202.620117
# 803  2025-03-18     19657.099609        3100.090088        3224.760010
# 804  2025-03-19     19576.320312        3078.689941        3202.840088
# 805  2025-03-20     19558.279297        3097.810059        3223.020020
# 806  2025-03-21     19466.439453        3083.290039        3207.830078
#
#      S&P 500_Open  Wilshire 5000_Open  NASDAQ 100_High  Russell 1000_High  \
# 0     4778.140137        48461.160156     16504.140625        2660.949951
# 1     4804.509766        48789.359375     16513.869141        2672.000000
# 2     4787.990234        48660.750000     16249.230469        2657.149902
# 3     4693.390137        47534.621094     15900.599609        2616.030029
# 4     4697.660156        47542.789062     15835.000000        2607.590088
# ..            ...                 ...              ...                ...
# 802   5635.600098        56252.058594     19943.810547        3119.679932
# 803   5654.529785        56672.839844     19676.050781        3100.090088
# 804   5632.370117        56063.410156     19921.619141        3127.000000
# 805   5646.919922        56715.878906     19888.849609        3125.179932
# 806   5630.729980        56569.429688     19767.980469        3102.120117
#
#      Russell 3000_High  S&P 500_High  ...  Russell 3000_Close  S&P 500_Close  \
# 0          2804.939941   4796.640137  ...         2804.929932    4796.560059
# 1          2817.110107   4818.620117  ...         2800.409912    4793.540039
# 2          2801.260010   4797.700195  ...         2739.340088    4700.580078
# 3          2756.689941   4725.009766  ...         2739.199951    4696.049805
# 4          2748.270020   4707.950195  ...         2725.600098    4677.029785
# ..                 ...           ...  ...                 ...            ...
# 802        3245.120117   5703.520020  ...         3229.610107    5675.120117
# 803        3224.760010   5654.529785  ...         3194.760010    5614.660156
# 804        3253.659912   5715.330078  ...         3231.800049    5675.290039
# 805        3251.580078   5711.149902  ...         3223.570068    5662.890137
# 806        3226.479980   5670.839844  ...         3224.929932    5667.560059
#
#      Wilshire 5000_Close  NASDAQ 100_Adj_Close  Russell 1000_Adj_Close  \
# 0           48789.359375          16501.769531             2660.780029
# 1           48660.750000          16279.730469             2656.489990
# 2           47534.621094          15771.780273             2600.530029
# 3           47542.789062          15765.360352             2599.429932
# 4           47321.140625          15592.190430             2587.729980
# ..                   ...                   ...                     ...
# 802         56672.839844          19812.240234             3104.459961
# 803         56063.410156          19483.359375             3070.689941
# 804         56715.878906          19736.660156             3105.699951
# 805         56569.429688          19677.609375             3098.360107
# 806         56595.609375          19753.970703             3100.550049
#
#      Russell 3000_Adj_Close  S&P 500_Adj_Close  Wilshire 5000_Adj_Close  \
# 0               2804.929932        4796.560059             48789.359375
# 1               2800.409912        4793.540039             48660.750000
# 2               2739.340088        4700.580078             47534.621094
# 3               2739.199951        4696.049805             47542.789062
# 4               2725.600098        4677.029785             47321.140625
# ..                      ...                ...                      ...
# 802             3229.610107        5675.120117             56672.839844
# 803             3194.760010        5614.660156             56063.410156
# 804             3231.800049        5675.290039             56715.878906
# 805             3223.570068        5662.890137             56569.429688
# 806             3224.929932        5667.560059             56595.609375
#
#      NASDAQ 100_Volume  S&P 500_Volume
# 0         4.429960e+09    3.831020e+09
# 1         5.131110e+09    4.683170e+09
# 2         5.031850e+09    4.887960e+09
# 3         4.790820e+09    4.295280e+09
# 4         4.238070e+09    4.181510e+09
# ..                 ...             ...
# 802       6.306340e+09    5.031770e+09
# 803       6.450530e+09    4.666270e+09
# 804       6.302310e+09    4.660090e+09
# 805       6.098330e+09    4.678420e+09
# 806       8.837930e+09    9.367460e+09
#
# [807 rows x 28 columns]

# %%
# Merge on "Date" and "Ticker" (adjust join type if needed)
combined_df = pd.merge(df_all, final_df_all, on=["Date", "Ticker"], how="inner")

# %%
# 5) (Optional) Merge with your main DataFrame on 'Date'
df_merged = pd.merge(
    combined_df,
    df_index_pivot,
    on='Date',    # or how='left'/'right'/'outer' if needed
    how='left'
)

df_merged
# Out:
#              Date        Open        High         Low       Close      Volume  \
# 0      2022-01-03  566.650024  575.000000  553.270020  564.369995   2862700.0
# 1      2022-01-04  563.900024  564.299988  541.309998  554.000000   4344800.0
# 2      2022-01-05  535.000000  538.750000  514.000000  514.429993   7394800.0
# 3      2022-01-06  510.000000  526.309998  508.200012  514.119995   3913600.0
# 4      2022-01-07  513.659973  520.419983  504.000000  510.700012   3605400.0
# ...           ...         ...         ...         ...         ...         ...
# 80034  2025-03-21  505.420013  510.079987  501.070007  503.200012   2280500.0
# 80035  2025-03-21   10.560000   10.790000   10.450000   10.740000  55497700.0
# 80036  2025-03-21  246.990005  250.190002  245.229996  249.490005   2831800.0
# 80037  2025-03-21   69.809998   70.360001   68.820000   69.110001   6689200.0
# 80038  2025-03-21  200.529999  206.500000  197.229996  205.199997   1826400.0
#
#          Market_Cap Ticker         IndClass_Sector  \
# 0      1.918454e+11   ADBE              Technology
# 1      1.918454e+11   ADBE              Technology
# 2      1.918454e+11   ADBE              Technology
# 3      1.918454e+11   ADBE              Technology
# 4      1.918454e+11   ADBE              Technology
# ...             ...    ...                     ...
# 80034  1.292167e+11   VRTX              Healthcare
# 80035  2.636412e+10    WBD  Communication Services
# 80036  6.636434e+10   WDAY              Technology
# 80037  3.970736e+10    XEL               Utilities
# 80038  3.174957e+10     ZS              Technology
#
#                     IndClass_Industry  ...  Russell 3000_Close  S&P 500_Close  \
# 0              Software - Application  ...         2804.929932    4796.560059
# 1              Software - Application  ...         2800.409912    4793.540039
# 2              Software - Application  ...         2739.340088    4700.580078
# 3              Software - Application  ...         2739.199951    4696.049805
# 4              Software - Application  ...         2725.600098    4677.029785
# ...                               ...  ...                 ...            ...
# 80034                   Biotechnology  ...         3224.929932    5667.560059
# 80035                   Entertainment  ...         3224.929932    5667.560059
# 80036          Software - Application  ...         3224.929932    5667.560059
# 80037  Utilities - Regulated Electric  ...         3224.929932    5667.560059
# 80038       Software - Infrastructure  ...         3224.929932    5667.560059
#
#        Wilshire 5000_Close  NASDAQ 100_Adj_Close  Russell 1000_Adj_Close  \
# 0             48789.359375          16501.769531             2660.780029
# 1             48660.750000          16279.730469             2656.489990
# 2             47534.621094          15771.780273             2600.530029
# 3             47542.789062          15765.360352             2599.429932
# 4             47321.140625          15592.190430             2587.729980
# ...                    ...                   ...                     ...
# 80034         56595.609375          19753.970703             3100.550049
# 80035         56595.609375          19753.970703             3100.550049
# 80036         56595.609375          19753.970703             3100.550049
# 80037         56595.609375          19753.970703             3100.550049
# 80038         56595.609375          19753.970703             3100.550049
#
#        Russell 3000_Adj_Close  S&P 500_Adj_Close  Wilshire 5000_Adj_Close  \
# 0                 2804.929932        4796.560059             48789.359375
# 1                 2800.409912        4793.540039             48660.750000
# 2                 2739.340088        4700.580078             47534.621094
# 3                 2739.199951        4696.049805             47542.789062
# 4                 2725.600098        4677.029785             47321.140625
# ...                       ...                ...                      ...
# 80034             3224.929932        5667.560059             56595.609375
# 80035             3224.929932        5667.560059             56595.609375
# 80036             3224.929932        5667.560059             56595.609375
# 80037             3224.929932        5667.560059             56595.609375
# 80038             3224.929932        5667.560059             56595.609375
#
#        NASDAQ 100_Volume  S&P 500_Volume
# 0           4.429960e+09    3.831020e+09
# 1           5.131110e+09    4.683170e+09
# 2           5.031850e+09    4.887960e+09
# 3           4.790820e+09    4.295280e+09
# 4           4.238070e+09    4.181510e+09
# ...                  ...             ...
# 80034       8.837930e+09    9.367460e+09
# 80035       8.837930e+09    9.367460e+09
# 80036       8.837930e+09    9.367460e+09
# 80037       8.837930e+09    9.367460e+09
# 80038       8.837930e+09    9.367460e+09
#
# [80039 rows x 128 columns]

# %%
filtered_df_merged = df_merged[df_merged['Ticker'].isin(company_list)]

filtered_df_merged
# Out:
#              Date        Open        High         Low       Close      Volume  \
# 0      2022-01-03  566.650024  575.000000  553.270020  564.369995   2862700.0
# 1      2022-01-04  563.900024  564.299988  541.309998  554.000000   4344800.0
# 2      2022-01-05  535.000000  538.750000  514.000000  514.429993   7394800.0
# 3      2022-01-06  510.000000  526.309998  508.200012  514.119995   3913600.0
# 4      2022-01-07  513.659973  520.419983  504.000000  510.700012   3605400.0
# ...           ...         ...         ...         ...         ...         ...
# 80034  2025-03-21  505.420013  510.079987  501.070007  503.200012   2280500.0
# 80035  2025-03-21   10.560000   10.790000   10.450000   10.740000  55497700.0
# 80036  2025-03-21  246.990005  250.190002  245.229996  249.490005   2831800.0
# 80037  2025-03-21   69.809998   70.360001   68.820000   69.110001   6689200.0
# 80038  2025-03-21  200.529999  206.500000  197.229996  205.199997   1826400.0
#
#          Market_Cap Ticker         IndClass_Sector  \
# 0      1.918454e+11   ADBE              Technology
# 1      1.918454e+11   ADBE              Technology
# 2      1.918454e+11   ADBE              Technology
# 3      1.918454e+11   ADBE              Technology
# 4      1.918454e+11   ADBE              Technology
# ...             ...    ...                     ...
# 80034  1.292167e+11   VRTX              Healthcare
# 80035  2.636412e+10    WBD  Communication Services
# 80036  6.636434e+10   WDAY              Technology
# 80037  3.970736e+10    XEL               Utilities
# 80038  3.174957e+10     ZS              Technology
#
#                     IndClass_Industry  ...  Russell 3000_Close  S&P 500_Close  \
# 0              Software - Application  ...         2804.929932    4796.560059
# 1              Software - Application  ...         2800.409912    4793.540039
# 2              Software - Application  ...         2739.340088    4700.580078
# 3              Software - Application  ...         2739.199951    4696.049805
# 4              Software - Application  ...         2725.600098    4677.029785
# ...                               ...  ...                 ...            ...
# 80034                   Biotechnology  ...         3224.929932    5667.560059
# 80035                   Entertainment  ...         3224.929932    5667.560059
# 80036          Software - Application  ...         3224.929932    5667.560059
# 80037  Utilities - Regulated Electric  ...         3224.929932    5667.560059
# 80038       Software - Infrastructure  ...         3224.929932    5667.560059
#
#        Wilshire 5000_Close  NASDAQ 100_Adj_Close  Russell 1000_Adj_Close  \
# 0             48789.359375          16501.769531             2660.780029
# 1             48660.750000          16279.730469             2656.489990
# 2             47534.621094          15771.780273             2600.530029
# 3             47542.789062          15765.360352             2599.429932
# 4             47321.140625          15592.190430             2587.729980
# ...                    ...                   ...                     ...
# 80034         56595.609375          19753.970703             3100.550049
# 80035         56595.609375          19753.970703             3100.550049
# 80036         56595.609375          19753.970703             3100.550049
# 80037         56595.609375          19753.970703             3100.550049
# 80038         56595.609375          19753.970703             3100.550049
#
#        Russell 3000_Adj_Close  S&P 500_Adj_Close  Wilshire 5000_Adj_Close  \
# 0                 2804.929932        4796.560059             48789.359375
# 1                 2800.409912        4793.540039             48660.750000
# 2                 2739.340088        4700.580078             47534.621094
# 3                 2739.199951        4696.049805             47542.789062
# 4                 2725.600098        4677.029785             47321.140625
# ...                       ...                ...                      ...
# 80034             3224.929932        5667.560059             56595.609375
# 80035             3224.929932        5667.560059             56595.609375
# 80036             3224.929932        5667.560059             56595.609375
# 80037             3224.929932        5667.560059             56595.609375
# 80038             3224.929932        5667.560059             56595.609375
#
#        NASDAQ 100_Volume  S&P 500_Volume
# 0           4.429960e+09    3.831020e+09
# 1           5.131110e+09    4.683170e+09
# 2           5.031850e+09    4.887960e+09
# 3           4.790820e+09    4.295280e+09
# 4           4.238070e+09    4.181510e+09
# ...                  ...             ...
# 80034       8.837930e+09    9.367460e+09
# 80035       8.837930e+09    9.367460e+09
# 80036       8.837930e+09    9.367460e+09
# 80037       8.837930e+09    9.367460e+09
# 80038       8.837930e+09    9.367460e+09
#
# [38315 rows x 128 columns]

# %%
filtered_df_merged.fillna(0, inplace=True)
# Out:
# /var/folders/74/m6y7v_2j0p53ss3v0zp9rtbc0000gn/T/ipykernel_95203/3409798551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_merged.fillna(0, inplace=True)

# %%
# Example of dropping non-numeric columns:
filtered_df_merged = filtered_df_merged.drop(columns=["IndClass_Sector", "IndClass_Industry"])

df_sorted = filtered_df_merged.sort_values(by='Date').reset_index(drop=True)

# Compute indices for splits
n = len(df_sorted)
train_end = int(n * 0.6)  # 60%
valid_end = int(n * 0.8)  # 80%

# Slice the DataFrame
df_train = df_sorted.iloc[:train_end]
df_valid = df_sorted.iloc[train_end:valid_end]
df_test = df_sorted.iloc[valid_end:]

df_train.fillna(0, inplace=True)
df_valid.fillna(0, inplace=True)
df_test.fillna(0, inplace=True)
# Out:
# /var/folders/74/m6y7v_2j0p53ss3v0zp9rtbc0000gn/T/ipykernel_95203/2795876467.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.fillna(0, inplace=True)
# /var/folders/74/m6y7v_2j0p53ss3v0zp9rtbc0000gn/T/ipykernel_95203/2795876467.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid.fillna(0, inplace=True)
# /var/folders/74/m6y7v_2j0p53ss3v0zp9rtbc0000gn/T/ipykernel_95203/2795876467.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.fillna(0, inplace=True)

# %%
def convert_data_qlibformat(df):
    import pandas as pd
    import numpy as np
    from qlib.data.dataset import TSDataSampler  # adjust import as needed

    # Create a copy to avoid SettingWithCopyWarning
    df = df.copy()
    
    # 1) Ensure the "Date" column is a datetime type
    df["Date"] = pd.to_datetime(df["Date"])
    
    # 2) Separate label and features BEFORE setting the index
    #    Retain "Date" and "Ticker" for indexing, but remove them from features.
    df_label = df[["Return"]].copy()
    # Exclude "Date" and "Ticker" along with "Return" from features
    df_feature = df.drop(columns=["Return", "Date", "Ticker"], errors="ignore")
    
    # 3) Normalize feature columns (ensure they are numeric)
    df_feature = df_feature.apply(pd.to_numeric, errors='coerce')
    feature_mean = df_feature.mean()
    feature_std = df_feature.std()
    eps = 1e-8  # to avoid division by zero
    normalized_feature = (df_feature - feature_mean) / (feature_std + eps)
    df_feature = normalized_feature
    
    # 4) Now set the index of the original DataFrame using "Date" and "Ticker"
    #    These columns will be used as the index ("datetime" and "instrument")
    df_index = df.set_index(["Date", "Ticker"])
    
    # 5) Assign the index to both label and feature DataFrames
    df_feature.index = df_index.index
    df_label.index = df_index.index

    # 6) Construct MultiIndex for the columns:
    #    For features, use top-level "feature"; for the label, use "label"
    df_feature.columns = pd.MultiIndex.from_product([["feature"], df_feature.columns])
    df_label.columns = pd.MultiIndex.from_product([["label"], df_label.columns])
    
    # 7) Concatenate features and label columns, and fill missing values with 0
    df_qlib = pd.concat([df_feature, df_label], axis=1)
    df_qlib = df_qlib.fillna(0)
    
    # 8) Name the index levels and sort the DataFrame
    df_qlib.index.names = ["datetime", "instrument"]
    df_qlib = df_qlib.sort_index(level=["datetime", "instrument"])

    
    # 9) Determine start and end dates from the datetime index level
    start = df_qlib.index.get_level_values("datetime").min()
    end = df_qlib.index.get_level_values("datetime").max()
    
    # 10) Build TSDataSampler (using fillna_type='ffill+bfill' for reindexing)
    sampler = TSDataSampler(df_qlib, start, end, step_len=8, fillna_type='ffill+bfill')
    sampler.data_arr = np.nan_to_num(sampler.data_arr, nan=0.0)
    
    return sampler

# Use the function for training, validation, and test sets:
dl_train = convert_data_qlibformat(df_train)
dl_valid = convert_data_qlibformat(df_valid)
dl_test = convert_data_qlibformat(df_test)

# %%
# Save the merged DataFrame tinpuo a pickle file
with open("training_input.pkl", "wb") as f:
    pickle.dump(dl_train, f)
with open("valid_input.pkl", "wb") as f:
    pickle.dump(dl_valid, f)
with open("testing_input.pkl", "wb") as f:
    pickle.dump(dl_test, f)

# %%
with open(f'training_input.pkl', 'rb') as f:
    dl_train = pickle.load(f)
with open(f'valid_input.pkl', 'rb') as f:
    dl_valid = pickle.load(f)
with open(f'testing_input.pkl', 'rb') as f:
    dl_test = pickle.load(f)

# %%
# After loading:
with open('training_input.pkl', 'rb') as f:
    ts_sampler = pickle.load(f)

print(type(ts_sampler))
print(dir(ts_sampler))
print(ts_sampler.__dict__)

# Extract the data array from the sampler
data_arr = ts_sampler.data_arr

# Convert the data array to a DataFrame
data_df = pd.DataFrame(data_arr)

# Display the DataFrame
print(data_df.head())

# Check for any NaN values in the data array
if np.isnan(data_arr).any():
    print("NaN found in ts_sampler.data_arr")
else:
    print("No NaN found in ts_sampler.data_arr")
# Out:
# <class 'qlib.data.dataset.TSDataSampler'>
# ['__annotations__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', '_get_indices', '_get_row_col', 'build_index', 'config', 'data_arr', 'data_index', 'empty', 'end', 'fillna_type', 'flt_idx_map', 'get_index', 'idx_arr', 'idx_df', 'idx_map', 'idx_map2arr', 'nan_idx', 'slice_idx_map_and_data_index', 'start', 'step_len']
# {'start': Timestamp('2022-01-03 00:00:00'), 'end': Timestamp('2023-12-12 00:00:00'), 'step_len': 8, 'fillna_type': 'ffill+bfill', 'data_arr': array([[-0.12984978, -0.12291   , -0.12327566, ..., -0.6788242 ,
#         -0.56645627,  0.        ],
#        [-0.11662426, -0.1227468 , -0.11934439, ...,  0.26410908,
#          0.41901375, -0.0126916 ],
#        [-0.12494533, -0.13028145, -0.13183531, ...,  0.13062044,
#          0.65584342, -0.02659988],
#        ...,
#        [-0.07427509, -0.06891635, -0.0678472 , ...,  0.66719742,
#         -0.7098678 , -0.00624844],
#        [-0.06771743, -0.05591434, -0.0609465 , ...,  0.90520688,
#         -0.57548816,  0.0335513 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]], shape=(22990, 124)), 'nan_idx': 22989, 'idx_df': instrument AAPL ABNB  ADBE   ADI   ADP  ADSK   AEP  AMAT   AMD  AMGN  ...  \
# datetime                                                              ...
# 2022-01-03    0  488   976  1464  1952  2440  2928  3416  3904  4392  ...
# 2022-01-04    1  489   977  1465  1953  2441  2929  3417  3905  4393  ...
# 2022-01-05    2  490   978  1466  1954  2442  2930  3418  3906  4394  ...
# 2022-01-06    3  491   979  1467  1955  2443  2931  3419  3907  4395  ...
# 2022-01-07    4  492   980  1468  1956  2444  2932  3420  3908  4396  ...
# ...         ...  ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2023-12-06  484  972  1460  1948  2436  2924  3412  3900  4388  4876  ...
# 2023-12-07  485  973  1461  1949  2437  2925  3413  3901  4389  4877  ...
# 2023-12-08  486  974  1462  1950  2438  2926  3414  3902  4390  4878  ...
# 2023-12-11  487  975  1463  1951  2439  2927  3415  3903  4391  4879  ...
# 2023-12-12  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# instrument   QCOM   REGN    ROP   ROST   TEAM   VRTX    WBD   WDAY    XEL  \
# datetime
# 2022-01-03  18109  18597  19085  19573  20061  20549  21037  21525  22013
# 2022-01-04  18110  18598  19086  19574  20062  20550  21038  21526  22014
# 2022-01-05  18111  18599  19087  19575  20063  20551  21039  21527  22015
# 2022-01-06  18112  18600  19088  19576  20064  20552  21040  21528  22016
# 2022-01-07  18113  18601  19089  19577  20065  20553  21041  21529  22017
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-12-06  18593  19081  19569  20057  20545  21033  21521  22009  22497
# 2023-12-07  18594  19082  19570  20058  20546  21034  21522  22010  22498
# 2023-12-08  18595  19083  19571  20059  20547  21035  21523  22011  22499
# 2023-12-11  18596  19084  19572  20060  20548  21036  21524  22012  22500
# 2023-12-12    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# instrument     ZS
# datetime
# 2022-01-03  22501
# 2022-01-04  22502
# 2022-01-05  22503
# 2022-01-06  22504
# 2022-01-07  22505
# ...           ...
# 2023-12-06  22985
# 2023-12-07  22986
# 2023-12-08  22987
# 2023-12-11  22988
# 2023-12-12    NaN
#
# [489 rows x 48 columns], 'idx_map': array([[  0,   0],
#        [  1,   0],
#        [  2,   0],
#        ...,
#        [485,  47],
#        [486,  47],
#        [487,  47]], shape=(22989, 2), dtype=int32), 'data_index': MultiIndex([('AAPL', '2022-01-03'),
#             ('AAPL', '2022-01-04'),
#             ('AAPL', '2022-01-05'),
#             ('AAPL', '2022-01-06'),
#             ('AAPL', '2022-01-07'),
#             ('AAPL', '2022-01-10'),
#             ('AAPL', '2022-01-11'),
#             ('AAPL', '2022-01-12'),
#             ('AAPL', '2022-01-13'),
#             ('AAPL', '2022-01-14'),
#             ...
#             (  'ZS', '2023-11-28'),
#             (  'ZS', '2023-11-29'),
#             (  'ZS', '2023-11-30'),
#             (  'ZS', '2023-12-01'),
#             (  'ZS', '2023-12-04'),
#             (  'ZS', '2023-12-05'),
#             (  'ZS', '2023-12-06'),
#             (  'ZS', '2023-12-07'),
#             (  'ZS', '2023-12-08'),
#             (  'ZS', '2023-12-11')],
#            names=['instrument', 'datetime'], length=22989), 'idx_arr': array([[0.0000e+00, 4.8800e+02, 9.7600e+02, ..., 2.1525e+04, 2.2013e+04,
#         2.2501e+04],
#        [1.0000e+00, 4.8900e+02, 9.7700e+02, ..., 2.1526e+04, 2.2014e+04,
#         2.2502e+04],
#        [2.0000e+00, 4.9000e+02, 9.7800e+02, ..., 2.1527e+04, 2.2015e+04,
#         2.2503e+04],
#        ...,
#        [4.8600e+02, 9.7400e+02, 1.4620e+03, ..., 2.2011e+04, 2.2499e+04,
#         2.2987e+04],
#        [4.8700e+02, 9.7500e+02, 1.4630e+03, ..., 2.2012e+04, 2.2500e+04,
#         2.2988e+04],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]], shape=(489, 48))}
#         0         1         2         3         4         5         6    \
# 0 -0.129850 -0.122910 -0.123276 -0.118491  4.715493  4.699604 -0.121561
# 1 -0.116624 -0.122747 -0.119344 -0.124851  4.456009  4.699604 -0.122332
# 2 -0.124945 -0.130281 -0.131835 -0.138010  4.216807  4.699604 -0.133374
# 3 -0.143985 -0.143528 -0.140200 -0.146049  4.335405  4.699604 -0.143278
# 4 -0.143461 -0.146684 -0.141901 -0.145581  3.824460  4.699604 -0.144746
#
#         7         8         9    ...       114       115       116       117  \
# 0 -0.616537 -1.626717 -0.063609  ...  2.324260  2.047175  2.011306  2.476784
# 1 -0.616537 -1.626717 -0.063609  ...  2.312936  2.009986  1.867867  2.447784
# 2 -0.616537 -1.626717 -0.063609  ...  1.964369  1.684360  1.539727  2.069505
# 3 -0.616537 -1.626717 -0.063609  ...  1.947382  1.686722  1.535579  2.062068
# 4 -0.126997 -1.626717 -0.063609  ...  1.876064  1.622631  1.423710  1.982978
#
#         118       119       120       121       122       123
# 0  2.588755  2.324260  2.047175 -0.678824 -0.566456  0.000000
# 1  2.559068  2.312936  2.009986  0.264109  0.419014 -0.012692
# 2  2.157971  1.964369  1.684360  0.130620  0.655843 -0.026600
# 3  2.157051  1.947382  1.686722 -0.193526 -0.029562 -0.016693
# 4  2.067730  1.876064  1.622631 -0.936885 -0.161132  0.000988
#
# [5 rows x 124 columns]
# No NaN found in ts_sampler.data_arr

# %%
for i, batch in enumerate(dl_valid):
    if i >= 237:
        print(f"Batch {i}:")
        print("  Type:", type(batch))            # Should be <class 'numpy.ndarray'>
        print("  Shape:", batch.shape)           # e.g. (batch_size, step_len, feature_dim)
        # Optionally, print some values:
        print("  Sample data:", batch[:2])       # First 2 samples
    if i >= 241:
        break
# Out:
# Batch 237:
#   Type: <class 'numpy.ndarray'>
#   Shape: (8, 124)
#   Sample data: [[-2.43289149e-01 -2.46306368e-01 -2.43858674e-01 -2.47532560e-01
#   -3.98698636e-01 -3.27665307e-01 -2.45911137e-01 -2.47725426e-01
#   -1.02644249e+00 -9.84453489e-01  5.75605359e-01 -1.20668605e+00
#    6.94164886e-01  3.23435797e-02  3.07358878e-01  5.21301495e-02
#    4.03111401e-02 -1.00542278e+00 -8.19620750e-02  4.91861806e-01
#    2.70295860e-01 -2.75257523e-01  7.67693536e-01  3.26863839e-01
#    1.23769223e+00 -1.05712015e+00 -1.51356829e+00  1.01558536e+00
#    6.90035928e-01  5.32010454e-02  2.90472390e-01  4.21161981e-01
#   -5.27609484e-01  2.51350197e-01 -1.12505228e-01  2.60720220e-01
#   -1.03690879e+00  1.33025863e-01  1.02295898e+00  1.11396153e+00
#   -6.86794743e-01  5.64957746e-01 -4.13951819e-01  2.42607067e-01
#   -4.26615144e-01 -3.27665307e-01 -2.61803461e-01 -2.54229024e-01
#   -1.56042971e+00 -2.95130421e-01  5.43157427e-02  1.47472187e+00
#    3.70223093e-02  3.23435797e-02  5.39927842e-01 -7.89034685e-02
#   -9.07397890e-02  1.40553406e-02 -9.82414901e-02 -5.16987814e-01
#    4.22778363e-02  2.51592037e-01  9.59941900e-02  7.74996039e-01
#   -1.94654872e-01  1.27109970e+00  8.41750937e-01  1.01558536e+00
#   -9.63162177e-02  1.68580281e-01  4.58174892e-01  3.89421838e-01
#    6.91292546e-01  8.17577704e-01 -1.28320785e-02  7.30227385e-01
#    1.26788132e+00  1.75538640e-01 -2.43752477e-01 -1.08165934e+00
#   -7.19054757e-01  4.23246437e-01 -6.93093259e-01  1.02795447e+00
#    1.42332379e+00 -1.64844159e-01 -4.82277110e-01 -5.01113242e-02
#   -7.46331472e-01 -8.05035118e-02 -8.86894684e-01  6.86579188e-01
#   -3.40685891e-01 -4.91215566e-02  1.61801831e-01 -1.93190728e-01
#    1.58352486e-01  1.15638784e-01  1.70590337e-04  8.42765847e-01
#   -2.76783826e-01  4.49180666e-01  1.48777935e-01 -7.38249927e-01
#   -6.32014375e-02  9.92006351e-01 -1.03513337e+00  2.60593152e-01
#   -1.01452541e+00  1.04957683e+00 -9.01176354e-01  1.38772109e+00
#   -1.24315850e-01 -1.54986485e+00  1.01003335e+00  9.82471231e-01
#   -1.31674406e+00 -3.20468099e-02  1.94034843e-01  1.08396560e+00
#    9.63160231e-01  1.13118644e+00  2.78681135e-02  0.00000000e+00
#    1.07451237e+00 -9.52095642e-02  1.28804616e+00  2.09378502e+00
#    1.18795401e+00  7.87173444e-03  1.15405946e+00  1.88539220e-01
#    6.72211450e-02  3.81184922e-01 -1.00897935e+00  4.00591120e-01
#   -1.28616114e-01  2.29507688e-01  2.30798284e-01  1.75757318e-01
#    2.69028924e-01 -4.85514405e-02  2.66076756e-01  2.71183801e-01
#    2.26232245e-01  2.53937812e-01 -3.21634419e-02  3.11305523e-01
#    3.13246307e-01  2.63384550e-01  3.20404163e-01 -2.78442547e-02
#    2.85067755e-01  2.95223470e-01  2.39966527e-01  2.85545669e-01
#   -2.78442547e-02  2.85067755e-01  2.95223470e-01  2.39966527e-01
#    2.85545669e-01 -3.56731254e-01 -3.29128420e-01 -4.80922035e-03]]

# %%
d_feat = 9
d_model = 256
t_nhead = 4
s_nhead = 2
dropout = 0.5
gate_input_start_index = 9
gate_input_end_index = 123

beta = 5

n_epoch = 100
lr = 1e-4
GPU = 0
train_stop_loss_thred = 0.001


ic = []
icir = []
ric = []
ricir = []

# %%
import numpy as np
import pandas as pd
import copy

from torch.utils.data import DataLoader
from torch.utils.data import Sampler
import torch
import torch.optim as optim

def calc_ic(pred, label):
    df = pd.DataFrame({'pred':pred, 'label':label})
    ic = df['pred'].corr(df['label'])
    ric = df['pred'].corr(df['label'], method='spearman')
    return ic, ric

def zscore(x):
    if x.numel() == 0:
        print(x) 
        print(x.std(unbiased=False))
    return (x - x.mean()).div(x.std())

def drop_extreme(x):
    sorted_tensor, indices = x.sort()
    N = x.shape[0]
    percent_2_5 = int(0.025*N)  
    # Exclude top 2.5% and bottom 2.5% values
    filtered_indices = indices[percent_2_5:-percent_2_5]
    mask = torch.zeros_like(x, device=x.device, dtype=torch.bool)
    mask[filtered_indices] = True
    return mask, x[mask]

def drop_na(x):
    N = x.shape[0]
    mask = ~x.isnan()
    return mask, x[mask]

class DailyBatchSamplerRandom(Sampler):
    def __init__(self, data_source, shuffle=False):
        self.data_source = data_source
        self.shuffle = shuffle
        # calculate number of samples in each batch
        
        self.daily_count = pd.Series(index=self.data_source.get_index()).groupby("datetime").size().values
        self.daily_index = np.roll(np.cumsum(self.daily_count), 1)  # calculate begin index of each batch
        self.daily_index[0] = 0

    def __iter__(self):
        if self.shuffle:
            index = np.arange(len(self.daily_count))
            np.random.shuffle(index)
            for i in index:
                yield np.arange(self.daily_index[i], self.daily_index[i] + self.daily_count[i])
        else:
            for idx, count in zip(self.daily_index, self.daily_count):
                yield np.arange(idx, idx + count)

    def __len__(self):
        return len(self.data_source)


class SequenceModel():
    def __init__(self, n_epochs, lr, GPU=None, seed=None, train_stop_loss_thred=None, save_path = 'model/', save_prefix= ''):
        self.n_epochs = n_epochs
        self.lr = lr
        self.device = torch.device(f"cuda:{GPU}" if torch.cuda.is_available() else "cpu")
        self.seed = seed
        self.train_stop_loss_thred = train_stop_loss_thred

        if self.seed is not None:
            np.random.seed(self.seed)
            torch.manual_seed(self.seed)
            torch.cuda.manual_seed_all(self.seed)
            torch.backends.cudnn.deterministic = True
        self.fitted = -1

        self.model = None
        self.train_optimizer = None

        self.save_path = save_path
        self.save_prefix = save_prefix


    def init_model(self):
        if self.model is None:
            raise ValueError("model has not been initialized")

        self.train_optimizer = optim.Adam(self.model.parameters(), self.lr)
        self.model.to(self.device)

    def loss_fn(self, pred, label):
        mask = ~torch.isnan(label)
        loss = (pred[mask]-label[mask])**2
        return torch.mean(loss)

    def train_epoch(self, data_loader):
        self.model.train()
        losses = []

        for data in data_loader:
            data = torch.squeeze(data, dim=0)
            '''
            data.shape: (N, T, F)
            N - number of stocks
            T - length of lookback_window, 8
            F - 158 factors + 63 market information + 1 label           
            '''
            feature = data[:, :, 0:-1].to(self.device)
            label = data[:, -1, -1].to(self.device)
            
            # Additional process on labels
            # If you use original data to train, you won't need the following lines because we already drop extreme when we dumped the data.
            # If you use the opensource data to train, use the following lines to drop extreme labels.
            #########################
            #mask, label = drop_extreme(label)
            #feature = feature[mask, :, :]
            #label = zscore(label) # CSZscoreNorm
            #########################

            pred = self.model(feature.float())    
            loss = self.loss_fn(pred, label)
            losses.append(loss.item())

            self.train_optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_value_(self.model.parameters(), 3.0)
            self.train_optimizer.step()
        
        return float(np.mean(losses))

    def test_epoch(self, data_loader):
        self.model.eval()
        losses = []

        for data in data_loader:
            data = torch.squeeze(data, dim=0)
            feature = data[:, :, 0:-1].to(self.device)
            label = data[:, -1, -1].to(self.device)

            # You cannot drop extreme labels for test. 
            label = zscore(label)
                        
            pred = self.model(feature.float())
            loss = self.loss_fn(pred, label)
            losses.append(loss.item())

        return float(np.mean(losses))

    def _init_data_loader(self, data, shuffle=True, drop_last=True):
        sampler = DailyBatchSamplerRandom(data, shuffle)
        data_loader = DataLoader(data, sampler=sampler, drop_last=drop_last)
        return data_loader

    def load_param(self, param_path):
        self.model.load_state_dict(torch.load(param_path, map_location=self.device))
        self.fitted = 'Previously trained.'

    def fit(self, dl_train, dl_valid=None):
        train_loader = self._init_data_loader(dl_train, shuffle=True, drop_last=True)
        best_param = None
        for step in range(self.n_epochs):
            train_loss = self.train_epoch(train_loader)
            self.fitted = step
            if dl_valid:
                predictions, metrics = self.predict(dl_valid)
                print("Epoch %d, train_loss %.6f, valid ic %.4f, icir %.3f, rankic %.4f, rankicir %.3f." % (step, train_loss, metrics['IC'],  metrics['ICIR'],  metrics['RIC'],  metrics['RICIR']))
            else: print("Epoch %d, train_loss %.6f" % (step, train_loss))
        
            if train_loss <= self.train_stop_loss_thred:
                best_param = copy.deepcopy(self.model.state_dict())
                torch.save(best_param, f'{self.save_path}/{self.save_prefix}_{self.seed}.pkl')
                break
        

        

    def predict(self, dl_test):
        # string cannot be compared with int,add one more condition here
        if isinstance(self.fitted,(int, float)) and self.fitted<0:
        #if self.fitted<0:
            raise ValueError("model is not fitted yet!")
        else:
            print('Epoch:', self.fitted)

        test_loader = self._init_data_loader(dl_test, shuffle=False, drop_last=False)

        preds = []
        ic = []
        ric = []

        self.model.eval()
        for data in test_loader:
            data = torch.squeeze(data, dim=0)
            feature = data[:, :, 0:-1].to(self.device)
            label = data[:, -1, -1]
            
            # nan label will be automatically ignored when compute metrics.
            # zscorenorm will not affect the results of ranking-based metrics.

            with torch.no_grad():
                pred = self.model(feature.float()).detach().cpu().numpy()
            preds.append(pred.ravel())

            daily_ic, daily_ric = calc_ic(pred, label.detach().numpy())
            ic.append(daily_ic)
            ric.append(daily_ric)

        predictions = pd.Series(np.concatenate(preds), index=dl_test.get_index())

        metrics = {
            'IC': np.mean(ic),
            'ICIR': np.mean(ic)/np.std(ic),
            'RIC': np.mean(ric),
            'RICIR': np.mean(ric)/np.std(ric)
        }

        return predictions, metrics

# %%
import torch
from torch import nn
from torch.nn.modules.linear import Linear
from torch.nn.modules.dropout import Dropout
from torch.nn.modules.normalization import LayerNorm
import math



class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=100):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer("pe", pe)

    def forward(self, x):
        return x + self.pe[:x.shape[1], :]


class SAttention(nn.Module):
    def __init__(self, d_model, nhead, dropout):
        super().__init__()

        self.d_model = d_model
        self.nhead = nhead
        self.temperature = math.sqrt(self.d_model/nhead)

        self.qtrans = nn.Linear(d_model, d_model, bias=False)
        self.ktrans = nn.Linear(d_model, d_model, bias=False)
        self.vtrans = nn.Linear(d_model, d_model, bias=False)

        attn_dropout_layer = []
        for i in range(nhead):
            attn_dropout_layer.append(Dropout(p=dropout))
        self.attn_dropout = nn.ModuleList(attn_dropout_layer)

        # input LayerNorm
        self.norm1 = LayerNorm(d_model, eps=1e-5)

        # FFN layerNorm
        self.norm2 = LayerNorm(d_model, eps=1e-5)
        self.ffn = nn.Sequential(
            Linear(d_model, d_model),
            nn.ReLU(),
            Dropout(p=dropout),
            Linear(d_model, d_model),
            Dropout(p=dropout)
        )

    def forward(self, x):
        x = self.norm1(x)
        q = self.qtrans(x).transpose(0,1)
        k = self.ktrans(x).transpose(0,1)
        v = self.vtrans(x).transpose(0,1)

        dim = int(self.d_model/self.nhead)
        att_output = []
        for i in range(self.nhead):
            if i==self.nhead-1:
                qh = q[:, :, i * dim:]
                kh = k[:, :, i * dim:]
                vh = v[:, :, i * dim:]
            else:
                qh = q[:, :, i * dim:(i + 1) * dim]
                kh = k[:, :, i * dim:(i + 1) * dim]
                vh = v[:, :, i * dim:(i + 1) * dim]

            atten_ave_matrixh = torch.softmax(torch.matmul(qh, kh.transpose(1, 2)) / self.temperature, dim=-1)
            if self.attn_dropout:
                atten_ave_matrixh = self.attn_dropout[i](atten_ave_matrixh)
            att_output.append(torch.matmul(atten_ave_matrixh, vh).transpose(0, 1))
        att_output = torch.concat(att_output, dim=-1)

        # FFN
        xt = x + att_output
        xt = self.norm2(xt)
        att_output = xt + self.ffn(xt)

        return att_output


class TAttention(nn.Module):
    def __init__(self, d_model, nhead, dropout):
        super().__init__()
        self.d_model = d_model
        self.nhead = nhead
        self.qtrans = nn.Linear(d_model, d_model, bias=False)
        self.ktrans = nn.Linear(d_model, d_model, bias=False)
        self.vtrans = nn.Linear(d_model, d_model, bias=False)

        self.attn_dropout = []
        if dropout > 0:
            for i in range(nhead):
                self.attn_dropout.append(Dropout(p=dropout))
            self.attn_dropout = nn.ModuleList(self.attn_dropout)

        # input LayerNorm
        self.norm1 = LayerNorm(d_model, eps=1e-5)
        # FFN layerNorm
        self.norm2 = LayerNorm(d_model, eps=1e-5)
        # FFN
        self.ffn = nn.Sequential(
            Linear(d_model, d_model),
            nn.ReLU(),
            Dropout(p=dropout),
            Linear(d_model, d_model),
            Dropout(p=dropout)
        )

    def forward(self, x):
        x = self.norm1(x)
        q = self.qtrans(x)
        k = self.ktrans(x)
        v = self.vtrans(x)

        dim = int(self.d_model / self.nhead)
        att_output = []
        for i in range(self.nhead):
            if i==self.nhead-1:
                qh = q[:, :, i * dim:]
                kh = k[:, :, i * dim:]
                vh = v[:, :, i * dim:]
            else:
                qh = q[:, :, i * dim:(i + 1) * dim]
                kh = k[:, :, i * dim:(i + 1) * dim]
                vh = v[:, :, i * dim:(i + 1) * dim]
            atten_ave_matrixh = torch.softmax(torch.matmul(qh, kh.transpose(1, 2)), dim=-1)
            if self.attn_dropout:
                atten_ave_matrixh = self.attn_dropout[i](atten_ave_matrixh)
            att_output.append(torch.matmul(atten_ave_matrixh, vh))
        att_output = torch.concat(att_output, dim=-1)

        # FFN
        xt = x + att_output
        xt = self.norm2(xt)
        att_output = xt + self.ffn(xt)

        return att_output


class Gate(nn.Module):
    def __init__(self, d_input, d_output,  beta=1.0):
        super().__init__()
        self.trans = nn.Linear(d_input, d_output)
        self.d_output =d_output
        self.t = beta

    def forward(self, gate_input):
        output = self.trans(gate_input)
        output = torch.softmax(output/self.t, dim=-1)
        return self.d_output*output


class TemporalAttention(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.trans = nn.Linear(d_model, d_model, bias=False)

    def forward(self, z):
        h = self.trans(z) # [N, T, D]
        query = h[:, -1, :].unsqueeze(-1)
        lam = torch.matmul(h, query).squeeze(-1)  # [N, T, D] --> [N, T]
        lam = torch.softmax(lam, dim=1).unsqueeze(1)
        output = torch.matmul(lam, z).squeeze(1)  # [N, 1, T], [N, T, D] --> [N, 1, D]
        return output


class MASTER(nn.Module):
    def __init__(self, d_feat, d_model, t_nhead, s_nhead, T_dropout_rate, S_dropout_rate, gate_input_start_index, gate_input_end_index, beta):
        super(MASTER, self).__init__()
        # market
        self.gate_input_start_index = gate_input_start_index
        self.gate_input_end_index = gate_input_end_index
        self.d_gate_input = (gate_input_end_index - gate_input_start_index) # F'
        self.feature_gate = Gate(self.d_gate_input, d_feat, beta=beta)

        self.layers = nn.Sequential(
            # feature layer
            nn.Linear(d_feat, d_model),
            PositionalEncoding(d_model),
            # intra-stock aggregation
            TAttention(d_model=d_model, nhead=t_nhead, dropout=T_dropout_rate),
            # inter-stock aggregation
            SAttention(d_model=d_model, nhead=s_nhead, dropout=S_dropout_rate),
            TemporalAttention(d_model=d_model),
            # decoder
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        src = x[:, :, :self.gate_input_start_index] # N, T, D
        gate_input = x[:, -1, self.gate_input_start_index:self.gate_input_end_index]
        src = src * torch.unsqueeze(self.feature_gate(gate_input), dim=1)
       
        output = self.layers(src).squeeze(-1)

        return output


class MASTERModel(SequenceModel):
    def __init__(
            self, d_feat, d_model, t_nhead, s_nhead, gate_input_start_index, gate_input_end_index,
            T_dropout_rate, S_dropout_rate, beta, **kwargs,
    ):
        super(MASTERModel, self).__init__(**kwargs)
        self.d_model = d_model
        self.d_feat = d_feat

        self.gate_input_start_index = gate_input_start_index
        self.gate_input_end_index = gate_input_end_index

        self.T_dropout_rate = T_dropout_rate
        self.S_dropout_rate = S_dropout_rate
        self.t_nhead = t_nhead
        self.s_nhead = s_nhead
        self.beta = beta

        self.init_model()

    def init_model(self):
        self.model = MASTER(d_feat=self.d_feat, d_model=self.d_model, t_nhead=self.t_nhead, s_nhead=self.s_nhead,
                                   T_dropout_rate=self.T_dropout_rate, S_dropout_rate=self.S_dropout_rate,
                                   gate_input_start_index=self.gate_input_start_index,
                                   gate_input_end_index=self.gate_input_end_index, beta=self.beta)
        super(MASTERModel, self).init_model()

# %%
#from master import MASTERModel

for seed in [0, 1, 2, 3, 4]:
    model = MASTERModel(
        d_feat = d_feat, d_model = d_model, t_nhead = t_nhead, s_nhead = s_nhead, T_dropout_rate=dropout, S_dropout_rate=dropout,
        beta=beta, gate_input_end_index=gate_input_end_index, gate_input_start_index=gate_input_start_index,
        n_epochs=n_epoch, lr = lr, GPU = GPU, seed = seed, train_stop_loss_thred = train_stop_loss_thred,
        save_path='model', save_prefix=f'model_training'
    )

    start = time.time()
    # Train
    model.fit(dl_train, dl_valid)

    print("Model Trained.")

    # Test
    predictions, metrics = model.predict(dl_test)
    
    running_time = time.time()-start

    print('Seed: {:d} time cost : {:.2f} sec'.format(seed, running_time))
    print(metrics)

    ic.append(metrics['IC'])
    icir.append(metrics['ICIR'])
    ric.append(metrics['RIC'])
    ricir.append(metrics['RICIR'])
# Out:
# Epoch: 0
# Epoch 0, train_loss 0.031807, valid ic 0.4159, icir 1.664, rankic 0.4438, rankicir 1.930.
# Epoch: 1
# Epoch 1, train_loss 0.004458, valid ic 0.5351, icir 2.523, rankic 0.5842, rankicir 3.015.
# Epoch: 2
# Epoch 2, train_loss 0.003333, valid ic 0.5956, icir 3.466, rankic 0.6165, rankicir 3.724.
# Epoch: 3
# Epoch 3, train_loss 0.001796, valid ic 0.5292, icir 3.301, rankic 0.5695, rankicir 3.909.
# Epoch: 4
# Epoch 4, train_loss 0.005339, valid ic 0.5801, icir 3.427, rankic 0.5982, rankicir 3.655.
# Epoch: 5
# Epoch 5, train_loss 0.001014, valid ic 0.5821, icir 2.943, rankic 0.6182, rankicir 3.152.
# Epoch: 6
# Epoch 6, train_loss 0.001245, valid ic 0.5607, icir 2.756, rankic 0.5900, rankicir 2.849.
# Epoch: 7
# Epoch 7, train_loss 0.001257, valid ic 0.5791, icir 2.648, rankic 0.6002, rankicir 2.543.
# Epoch: 8
# Epoch 8, train_loss 0.001393, valid ic 0.6030, icir 2.948, rankic 0.6108, rankicir 2.806.
# Epoch: 9
# Epoch 9, train_loss 0.001566, valid ic 0.6781, icir 4.594, rankic 0.6863, rankicir 4.120.
# Epoch: 10
# Epoch 10, train_loss 0.000810, valid ic 0.7408, icir 5.814, rankic 0.7535, rankicir 5.237.
# Model Trained.
# Epoch: 10
# Seed: 0 time cost : 102.89 sec
# {'IC': np.float64(0.744734238730873), 'ICIR': np.float64(8.485826422776752), 'RIC': np.float64(0.7600683090616813), 'RICIR': np.float64(7.313945772590813)}
# Epoch: 0
# Epoch 0, train_loss 0.033762, valid ic 0.0969, icir 0.516, rankic 0.1202, rankicir 0.659.
# Epoch: 1
# Epoch 1, train_loss 0.003602, valid ic 0.2443, icir 1.281, rankic 0.2693, rankicir 1.518.
# Epoch: 2
# Epoch 2, train_loss 0.001567, valid ic 0.3478, icir 1.620, rankic 0.3852, rankicir 1.885.
# Epoch: 3
# Epoch 3, train_loss 0.001754, valid ic 0.3703, icir 1.790, rankic 0.4003, rankicir 1.950.
# Epoch: 4
# Epoch 4, train_loss 0.002455, valid ic 0.4766, icir 2.085, rankic 0.5202, rankicir 2.237.
# Epoch: 5
# Epoch 5, train_loss 0.003470, valid ic 0.5405, icir 2.131, rankic 0.5789, rankicir 2.176.
# Epoch: 6
# Epoch 6, train_loss 0.001333, valid ic 0.5704, icir 2.453, rankic 0.6140, rankicir 2.508.
# Epoch: 7
# Epoch 7, train_loss 0.000785, valid ic 0.5940, icir 2.585, rankic 0.6326, rankicir 2.632.
# Model Trained.
# Epoch: 7
# Seed: 1 time cost : 72.57 sec
# {'IC': np.float64(0.5991998204336625), 'ICIR': np.float64(3.231271140140605), 'RIC': np.float64(0.6379826952435648), 'RICIR': np.float64(3.1440600844878848)}
# Epoch: 0
# Epoch 0, train_loss 0.024850, valid ic 0.1477, icir 0.912, rankic 0.1535, rankicir 0.944.
# Epoch: 1
# Epoch 1, train_loss 0.003200, valid ic 0.3439, icir 2.295, rankic 0.3639, rankicir 2.582.
# Epoch: 2
# Epoch 2, train_loss 0.004406, valid ic 0.2493, icir 1.269, rankic 0.2621, rankicir 1.375.
# Epoch: 3
# Epoch 3, train_loss 0.001649, valid ic 0.4617, icir 2.688, rankic 0.4769, rankicir 2.873.
# Epoch: 4
# Epoch 4, train_loss 0.002223, valid ic 0.4771, icir 2.728, rankic 0.5018, rankicir 3.050.
# Epoch: 5
# Epoch 5, train_loss 0.001247, valid ic 0.4676, icir 1.923, rankic 0.5008, rankicir 1.937.
# Epoch: 6
# Epoch 6, train_loss 0.001118, valid ic 0.5501, icir 2.428, rankic 0.5808, rankicir 2.499.
# Epoch: 7
# Epoch 7, train_loss 0.001636, valid ic 0.5468, icir 2.076, rankic 0.5843, rankicir 2.151.
# Epoch: 8
# Epoch 8, train_loss 0.001451, valid ic 0.5481, icir 1.987, rankic 0.5956, rankicir 2.148.
# Epoch: 9
# Epoch 9, train_loss 0.002176, valid ic 0.6482, icir 2.956, rankic 0.6829, rankicir 2.963.
# Epoch: 10
# Epoch 10, train_loss 0.001800, valid ic 0.6655, icir 3.323, rankic 0.6980, rankicir 3.132.
# Epoch: 11
# Epoch 11, train_loss 0.000480, valid ic 0.7348, icir 4.526, rankic 0.7539, rankicir 4.066.
# Model Trained.
# Epoch: 11
# Seed: 2 time cost : 111.43 sec
# {'IC': np.float64(0.7431602909669189), 'ICIR': np.float64(6.0602123689545095), 'RIC': np.float64(0.7654838423539359), 'RICIR': np.float64(5.083094002562934)}
# Epoch: 0
# Epoch 0, train_loss 0.029612, valid ic 0.1423, icir 0.721, rankic 0.1699, rankicir 0.928.
# Epoch: 1
# Epoch 1, train_loss 0.004532, valid ic 0.2708, icir 1.534, rankic 0.3098, rankicir 1.890.
# Epoch: 2
# Epoch 2, train_loss 0.003439, valid ic 0.3605, icir 2.100, rankic 0.3982, rankicir 2.442.
# Epoch: 3
# Epoch 3, train_loss 0.005873, valid ic 0.4527, icir 2.193, rankic 0.4940, rankicir 2.564.
# Epoch: 4
# Epoch 4, train_loss 0.001146, valid ic 0.5341, icir 2.671, rankic 0.5881, rankicir 2.976.
# Epoch: 5
# Epoch 5, train_loss 0.001636, valid ic 0.5910, icir 3.074, rankic 0.6382, rankicir 3.439.
# Epoch: 6
# Epoch 6, train_loss 0.002660, valid ic 0.5182, icir 1.549, rankic 0.5429, rankicir 1.602.
# Epoch: 7
# Epoch 7, train_loss 0.000876, valid ic 0.7200, icir 5.174, rankic 0.7615, rankicir 5.911.
# Model Trained.
# Epoch: 7
# Seed: 3 time cost : 74.21 sec
# {'IC': np.float64(0.710110464596724), 'ICIR': np.float64(5.86757779956987), 'RIC': np.float64(0.7489829609257708), 'RICIR': np.float64(6.251140089966885)}
# Epoch: 0
# Epoch 0, train_loss 0.032554, valid ic 0.0481, icir 0.303, rankic 0.0347, rankicir 0.200.
# Epoch: 1
# Epoch 1, train_loss 0.008639, valid ic 0.1239, icir 0.774, rankic 0.1202, rankicir 0.698.
# Epoch: 2
# Epoch 2, train_loss 0.002134, valid ic 0.2395, icir 1.658, rankic 0.2365, rankicir 1.467.
# Epoch: 3
# Epoch 3, train_loss 0.002178, valid ic 0.3392, icir 1.876, rankic 0.3492, rankicir 1.774.
# Epoch: 4
# Epoch 4, train_loss 0.002618, valid ic 0.4204, icir 2.092, rankic 0.4399, rankicir 2.123.
# Epoch: 5
# Epoch 5, train_loss 0.001198, valid ic 0.4767, icir 2.615, rankic 0.4949, rankicir 2.621.
# Epoch: 6
# Epoch 6, train_loss 0.002388, valid ic 0.5168, icir 2.785, rankic 0.5418, rankicir 2.708.
# Epoch: 7
# Epoch 7, train_loss 0.001553, valid ic 0.5940, icir 3.208, rankic 0.6196, rankicir 3.091.
# Epoch: 8
# Epoch 8, train_loss 0.001399, valid ic 0.6573, icir 4.557, rankic 0.6875, rankicir 4.201.
# Epoch: 9
# Epoch 9, train_loss 0.000653, valid ic 0.7449, icir 6.978, rankic 0.7778, rankicir 6.475.
# Model Trained.
# Epoch: 9
# Seed: 4 time cost : 91.08 sec
# {'IC': np.float64(0.7064914083717329), 'ICIR': np.float64(5.097134054993593), 'RIC': np.float64(0.7429253476972119), 'RICIR': np.float64(4.999782291329493)}

# %%
# Load and Test
######################################################################################
for seed in [0]:
    param_path = f'model/model_training_{seed}.pkl'

    print(f'Model Loaded from {param_path}')
    model = MASTERModel(
            d_feat = d_feat, d_model = d_model, t_nhead = t_nhead, s_nhead = s_nhead, T_dropout_rate=dropout, S_dropout_rate=dropout,
            beta=beta, gate_input_end_index=gate_input_end_index, gate_input_start_index=gate_input_start_index,
            n_epochs=n_epoch, lr = lr, GPU = GPU, seed = seed, train_stop_loss_thred = train_stop_loss_thred,
            save_path='model', save_prefix=f'model_prediction'
        )
    model.load_param(param_path)
    predictions, metrics = model.predict(dl_test)
    print(metrics)

    ic.append(metrics['IC'])
    icir.append(metrics['ICIR'])
    ric.append(metrics['RIC'])
    ricir.append(metrics['RICIR'])
    
######################################################################################

print("IC: {:.4f} pm {:.4f}".format(np.mean(ic), np.std(ic)))
print("ICIR: {:.4f} pm {:.4f}".format(np.mean(icir), np.std(icir)))
print("RIC: {:.4f} pm {:.4f}".format(np.mean(ric), np.std(ric)))
print("RICIR: {:.4f} pm {:.4f}".format(np.mean(ricir), np.std(ricir)))
# Out:
# Model Loaded from model/model_training_0.pkl
# Epoch: Previously trained.
# {'IC': np.float64(0.744734238730873), 'ICIR': np.float64(8.485826422776752), 'RIC': np.float64(0.7600683090616813), 'RICIR': np.float64(7.313945772590813)}
# IC: 0.7081 pm 0.0513
# ICIR: 6.2046 pm 1.8534
# RIC: 0.7359 pm 0.0444
# RICIR: 5.6843 pm 1.4672
